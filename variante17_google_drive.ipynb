# %% [markdown]
# <a href="https://colab.research.google.com/github/Pascoalpm/lab-jupyter-autovalores/blob/main/variante17_google_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Célula 1: Montar o Drive (executa primeiro)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-3521/2070235497.py in <cell line: 0>()
#       1 # Célula 1: Montar o Drive (executa primeiro)
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
# Guardar arquivos LOCALMENTE no Colab
with open("my_text_file.txt", "w") as f:
    f.write("First line\nSecond line\nVariant 17: Matrix eigenvalues\n")

# Criar CSV com nomes
students = [
    ["Pascoal Mendes", 20, "IBT-b-o-24-1"],
    ["Lemos Arnaldo", 22, "IBT-b-o-24-1"],
    ["Danil ", 21, "IBT-b-o-24-1"],
    ["Victor ", 23, "IBT-b-o-24-1"]
]

with open("students.csv", "w") as f:
    f.write("Name,Age,Group\n")
    for s in students:
        f.write(f"{s[0]},{s[1]},{s[2]}\n")

# Download dos arquivos
from google.colab import files
files.download("my_text_file.txt")
files.download("students.csv")

print("✅ Arquivos baixados!")
# Out:
# ✅ Arquivos baixados!
